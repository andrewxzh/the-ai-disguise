# %%
from src.estimation import estimate_text_distribution
from src.MLE import MLE
import pandas as pd

# %%
# for each subject, estimate the distribution of human-written text and AI-generated text
for name in ["CS","EESS","Math","Phys","Stat"]:
    estimate_text_distribution(f"data/training_data/{name}/human_data.parquet",f"data/training_data/{name}/ai_data.parquet",f"distribution/{name}.parquet")

# %%
pd.read_parquet("data/training_data/CS/human_data.parquet")
# Out:
#                                           human_sentence  \
# 0      [particularly the, the proposed, proposed spre...
# 1      [this mixed, mixed approach, approach has, has...
# 2      [firstly observing, observing the, the limited...
# 3      [however existing, existing methods, methods e...
# 4      [in this, this task, task a, a fused, fused im...
# ...                                                  ...
# 37855  [active learning, learning shows, shows promis...
# 37856  [finally simulations, simulations using, using...
# 37857  [in this, this paper, paper we, we model, mode...
# 37858  [these results, results help, help to, to iden...
# 37859  [intuitively a, a shorter, shorter tree, tree ...
#
#                                                 sentence
# 0      particularly the proposed spreading curve view...
# 1      this mixed approach has rarely been applied in...
# 2      firstly observing the limited rotation invaria...
# 3      however existing methods either require expens...
# 4      in this task a fused image containing both the...
# ...                                                  ...
# 37855  active learning shows promise to decrease test...
# 37856  finally simulations using flashflow for load b...
# 37857  in this paper we model this intention as a lat...
# 37858  these results help to identify the most critic...
# 37859  intuitively a shorter tree with pure leaves ge...
#
# [37860 rows x 2 columns]

# %%
pd.read_parquet("data/validation_data/CS/ground_truth_alpha_0.1.parquet")
# Out:
#                                       inference_sentence  \
# 0      [however empirical, empirical studies, studies...
# 1      [inspired by, by our, our work, work on, on de...
# 2      [however if, if attacked, attacked it, it coul...
# 3      [existing methods, methods for, for speaker, s...
# 4      [estimation of, of the, the heart, heart rate,...
# ...                                                  ...
# 29995  [while achieving, achieving over, over times, ...
# 29996  [moreover the, the research, research provides...
# 29997  [one approach, approach to, to enhance, enhanc...
# 29998  [exploiting internal, internal spatial, spatia...
# 29999  [down sampling, sampling training, training da...
#
#                                                 sentence
# 0      however empirical studies show that linearizin...
# 1      inspired by our work on deep multimodal learni...
# 2      however if attacked it could still be compromi...
# 3      existing methods for speaker age estimation us...
# 4      estimation of the heart rate from facial video...
# ...                                                  ...
# 29995       while achieving over times inference speedup
# 29996  moreover the research provides theoretical evi...
# 29997  one approach to enhance secrecy is by studying...
# 29998  exploiting internal spatial geometric constrai...
# 29999  down sampling training data has long been show...
#
# [30000 rows x 2 columns]

# %%
# for each subject, estimate the alpha value of mixed text and calculate the error
for name in ["CS","EESS","Math","Phys","Stat"]:
    # load the framework
    print(name + " Results:")
    model=MLE(f"distribution/{name}.parquet")
    for alpha in [0,0.025,0.05,0.075,0.1,0.125,0.15,0.175,0.2,0.225,0.25]:
        estimated,ci=model.inference(f"data/validation_data/{name}/ground_truth_alpha_{alpha}.parquet")
        error=abs(estimated-alpha)
        print(f"{'Ground Truth':>10},{'Prediction':>10},{'CI':>10},{'Error':>10}")
        print(f"{alpha:10.3f},{estimated:10.3f},{ci:10.3f},{error:10.3f}")
    print("=====================================")
# Out:
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.037,     0.003,     0.037
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.066,     0.003,     0.041
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.091,     0.004,     0.041
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.113,     0.004,     0.038
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.140,     0.005,     0.040
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.162,     0.005,     0.037
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.182,     0.005,     0.032
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.206,     0.005,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.231,     0.005,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.254,     0.006,     0.029
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.278,     0.006,     0.028
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.045,     0.003,     0.045
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.073,     0.004,     0.048
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.096,     0.004,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.121,     0.004,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.144,     0.005,     0.044
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.168,     0.005,     0.043
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.189,     0.005,     0.039
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.208,     0.005,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.237,     0.005,     0.037
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.255,     0.005,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.280,     0.006,     0.030
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.031,     0.003,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.057,     0.003,     0.032
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.086,     0.004,     0.036
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.110,     0.004,     0.035
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.130,     0.004,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.160,     0.005,     0.035
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.181,     0.005,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.203,     0.005,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.229,     0.006,     0.029
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.254,     0.006,     0.029
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.274,     0.006,     0.024
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.041,     0.003,     0.041
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.066,     0.003,     0.041
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.090,     0.004,     0.040
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.113,     0.004,     0.038
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.137,     0.005,     0.037
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.161,     0.005,     0.036
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.180,     0.005,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.203,     0.005,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.223,     0.005,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.248,     0.006,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.267,     0.006,     0.017
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.038,     0.003,     0.038
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.070,     0.004,     0.045
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.093,     0.004,     0.043
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.117,     0.004,     0.042
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.140,     0.005,     0.040
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.164,     0.005,     0.039
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.183,     0.005,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.208,     0.005,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.227,     0.005,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.251,     0.006,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.276,     0.006,     0.026
# =====================================

# %%
# for each subject, estimate the alpha value of mixed text and calculate the error with only a specifc wordphrase vocabulary 

# Open the file in write mode with 
for part_of_speech in ['adj', 'verb', 'adv']:
    with open(f"results_{part_of_speech}.txt", "w") as file:
        print(f"Results for vocabulary with just {part_of_speech}\n\n")
        file.write(f"Results for vocabulary with just {part_of_speech}\n\n")
        for name in ["CS", "EESS", "Math", "Phys", "Stat"]:
        # Load the framework
            print(name + " Results:")
            file.write(f"{name} Results:\n")
            model = MLE(f"distribution/{name}.parquet", pos=part_of_speech)
            for alpha in [0, 0.025, 0.05, 0.075, 0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25]:
                estimated, ci = model.inference(f"data/validation_data/{name}/ground_truth_alpha_{alpha}.parquet")
                error = abs(estimated - alpha)
                line_header = f"{'Ground Truth':>10},{'Prediction':>10},{'CI':>10},{'Error':>10}"
                line_data = f"{alpha:10.3f},{estimated:10.3f},{ci:10.3f},{error:10.3f}"
                print(line_header)
                print(line_data)
                file.write(line_header + "\n")
                file.write(line_data + "\n")
            print("=====================================")
            file.write("=====================================\n")
# Out:
# Results for vocabulary with just adj
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.016,     0.006,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.044,     0.007,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.062,     0.008,     0.012
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.082,     0.008,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.112,     0.009,     0.012
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.128,     0.010,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.149,     0.010,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.174,     0.011,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.194,     0.011,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.222,     0.011,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.244,     0.011,     0.006
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.034,     0.007,     0.034
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.046,     0.008,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.071,     0.008,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.084,     0.009,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.122,     0.009,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.133,     0.010,     0.008
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.163,     0.011,     0.013
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.185,     0.011,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.206,     0.011,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.215,     0.011,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.255,     0.011,     0.005
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.031,     0.006,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.053,     0.007,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.081,     0.008,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.109,     0.009,     0.034
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.137,     0.010,     0.037
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.169,     0.010,     0.044
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.189,     0.010,     0.039
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.226,     0.011,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.249,     0.011,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.276,     0.012,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.304,     0.012,     0.054
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.018,     0.006,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.036,     0.008,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.076,     0.009,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.093,     0.009,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.120,     0.010,     0.020
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.155,     0.010,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.175,     0.011,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.205,     0.011,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.216,     0.011,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.251,     0.012,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.266,     0.013,     0.016
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.016,     0.006,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.048,     0.008,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.063,     0.008,     0.013
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.093,     0.009,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.120,     0.010,     0.020
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.135,     0.010,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.164,     0.011,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.179,     0.010,     0.004
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.216,     0.012,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.235,     0.012,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.258,     0.012,     0.008
# =====================================
# Results for vocabulary with just verb
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.031,     0.007,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.063,     0.008,     0.038
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.088,     0.008,     0.038
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.124,     0.009,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.149,     0.010,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.171,     0.010,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.195,     0.010,     0.045
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.221,     0.010,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.253,     0.011,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.274,     0.011,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.297,     0.011,     0.047
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.046,     0.008,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.082,     0.009,     0.057
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.111,     0.009,     0.061
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.141,     0.010,     0.066
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.169,     0.010,     0.069
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.199,     0.011,     0.074
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.223,     0.011,     0.073
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.252,     0.011,     0.077
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.287,     0.010,     0.087
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.301,     0.012,     0.076
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.338,     0.012,     0.088
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.040,     0.008,     0.040
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.078,     0.009,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.108,     0.008,     0.058
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.155,     0.010,     0.080
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.181,     0.010,     0.081
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.216,     0.010,     0.091
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.248,     0.010,     0.098
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.279,     0.011,     0.104
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.302,     0.011,     0.102
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.338,     0.011,     0.113
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.361,     0.011,     0.111
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.046,     0.008,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.076,     0.008,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.113,     0.009,     0.063
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.146,     0.009,     0.071
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.172,     0.009,     0.072
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.207,     0.011,     0.082
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.230,     0.010,     0.080
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.258,     0.010,     0.083
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.275,     0.011,     0.075
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.312,     0.010,     0.087
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.337,     0.011,     0.087
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.034,     0.007,     0.034
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.069,     0.008,     0.044
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.099,     0.008,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.120,     0.009,     0.045
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.144,     0.009,     0.044
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.175,     0.009,     0.050
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.201,     0.010,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.224,     0.010,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.248,     0.010,     0.048
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.273,     0.010,     0.048
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.304,     0.010,     0.054
# =====================================
# Results for vocabulary with just adv
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.033,     0.009,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.057,     0.010,     0.032
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.074,     0.010,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.094,     0.011,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.122,     0.012,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.144,     0.012,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.166,     0.013,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.180,     0.013,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.217,     0.015,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.236,     0.014,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.255,     0.014,     0.005
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.029,     0.008,     0.029
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.063,     0.010,     0.038
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.066,     0.011,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.101,     0.012,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.124,     0.012,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.149,     0.014,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.169,     0.014,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.187,     0.014,     0.012
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.216,     0.015,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.228,     0.014,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.265,     0.014,     0.015
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.009,     0.004,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.032,     0.007,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.062,     0.009,     0.012
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.084,     0.009,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.103,     0.011,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.126,     0.012,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.147,     0.012,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.164,     0.013,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.203,     0.013,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.219,     0.014,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.252,     0.015,     0.002
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.022,     0.007,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.054,     0.009,     0.029
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.072,     0.010,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.087,     0.010,     0.012
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.117,     0.012,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.140,     0.012,     0.015
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.167,     0.012,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.183,     0.013,     0.008
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.209,     0.014,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.243,     0.014,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.261,     0.015,     0.011
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.018,     0.006,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.049,     0.009,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.067,     0.009,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.085,     0.010,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.115,     0.011,     0.015
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.144,     0.012,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.149,     0.012,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.175,     0.013,     0.000
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.201,     0.012,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.222,     0.014,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.249,     0.014,     0.001
# =====================================
