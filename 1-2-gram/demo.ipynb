# %%
from src.estimation import estimate_text_distribution
from src.MLE import MLE
import pandas as pd

# %%
# for each subject, estimate the distribution of human-written text and AI-generated text
for name in ["CS","EESS","Math","Phys","Stat"]:
    estimate_text_distribution(f"data/training_data/{name}/human_data.parquet",f"data/training_data/{name}/ai_data.parquet",f"distribution/{name}.parquet")

# %%
pd.read_parquet("data/training_data/CS/human_data.parquet")
# Out:
#                                           human_sentence  \
# 0      [particularly, the, proposed, spreading, curve...
# 1      [this, mixed, approach, has, rarely, been, app...
# 2      [firstly, observing, the, limited, rotation, i...
# 3      [however, existing, methods, either, require, ...
# 4      [in, this, task, a, fused, image, containing, ...
# ...                                                  ...
# 37855  [active, learning, shows, promise, to, decreas...
# 37856  [finally, simulations, using, flashflow, for, ...
# 37857  [in, this, paper, we, model, this, intention, ...
# 37858  [these, results, help, to, identify, the, most...
# 37859  [intuitively, a, shorter, tree, with, pure, le...
#
#                                                 sentence
# 0      particularly the proposed spreading curve view...
# 1      this mixed approach has rarely been applied in...
# 2      firstly observing the limited rotation invaria...
# 3      however existing methods either require expens...
# 4      in this task a fused image containing both the...
# ...                                                  ...
# 37855  active learning shows promise to decrease test...
# 37856  finally simulations using flashflow for load b...
# 37857  in this paper we model this intention as a lat...
# 37858  these results help to identify the most critic...
# 37859  intuitively a shorter tree with pure leaves ge...
#
# [37860 rows x 2 columns]

# %%
pd.read_parquet("data/validation_data/CS/ground_truth_alpha_0.1.parquet")
# Out:
#                                       inference_sentence  \
# 0      [however, empirical, studies, show, that, line...
# 1      [inspired, by, our, work, on, deep, multimodal...
# 2      [however, if, attacked, it, could, still, be, ...
# 3      [existing, methods, for, speaker, age, estimat...
# 4      [estimation, of, the, heart, rate, from, facia...
# ...                                                  ...
# 29995  [while, achieving, over, times, inference, spe...
# 29996  [moreover, the, research, provides, theoretica...
# 29997  [one, approach, to, enhance, secrecy, is, by, ...
# 29998  [exploiting, internal, spatial, geometric, con...
# 29999  [down, sampling, training, data, has, long, be...
#
#                                                 sentence
# 0      however empirical studies show that linearizin...
# 1      inspired by our work on deep multimodal learni...
# 2      however if attacked it could still be compromi...
# 3      existing methods for speaker age estimation us...
# 4      estimation of the heart rate from facial video...
# ...                                                  ...
# 29995       while achieving over times inference speedup
# 29996  moreover the research provides theoretical evi...
# 29997  one approach to enhance secrecy is by studying...
# 29998  exploiting internal spatial geometric constrai...
# 29999  down sampling training data has long been show...
#
# [30000 rows x 2 columns]

# %%
# Open the file in write mode
with open("results.txt", "w") as file:
    # for each subject, estimate the alpha value of mixed text and calculate the error
    for name in ["CS", "EESS", "Math", "Phys", "Stat"]:
        # Load the framework
        print(name + " Results:")
        file.write(f"{name} Results:\n")
        model = MLE(f"distribution/{name}.parquet")
        for alpha in [0, 0.025, 0.05, 0.075, 0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25]:
            estimated, ci = model.inference(f"data/validation_data/{name}/ground_truth_alpha_{alpha}.parquet")
            error = abs(estimated - alpha)
            line_header = f"{'Ground Truth':>10},{'Prediction':>10},{'CI':>10},{'Error':>10}"
            line_data = f"{alpha:10.3f},{estimated:10.3f},{ci:10.3f},{error:10.3f}"
            print(line_header)
            print(line_data)
            file.write(line_header + "\n")
            file.write(line_data + "\n")
        print("=====================================")
        file.write("=====================================\n")
# Out:
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.046,     0.003,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.074,     0.003,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.097,     0.004,     0.047
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.117,     0.004,     0.042
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.141,     0.004,     0.041
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.164,     0.004,     0.039
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.185,     0.004,     0.035
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.205,     0.005,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.231,     0.005,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.251,     0.005,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.275,     0.005,     0.025
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.051,     0.003,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.075,     0.003,     0.050
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.098,     0.004,     0.048
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.122,     0.004,     0.047
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.144,     0.004,     0.044
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.165,     0.004,     0.040
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.186,     0.005,     0.036
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.206,     0.005,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.232,     0.005,     0.032
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.251,     0.005,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.274,     0.005,     0.024
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.034,     0.002,     0.034
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.056,     0.003,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.081,     0.003,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.102,     0.004,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.121,     0.004,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.146,     0.004,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.166,     0.004,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.186,     0.005,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.210,     0.005,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.234,     0.005,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.252,     0.005,     0.002
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.045,     0.003,     0.045
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.068,     0.003,     0.043
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.089,     0.004,     0.039
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.111,     0.004,     0.036
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.133,     0.004,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.156,     0.004,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.178,     0.005,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.199,     0.005,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.218,     0.005,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.239,     0.005,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.261,     0.005,     0.011
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.041,     0.003,     0.041
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.071,     0.003,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.092,     0.003,     0.042
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.114,     0.004,     0.039
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.135,     0.004,     0.035
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.158,     0.004,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.179,     0.005,     0.029
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.202,     0.005,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.221,     0.005,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.244,     0.005,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.266,     0.005,     0.016
# =====================================

# %%
# for each subject, estimate the alpha value of mixed text and calculate the error with only a specifc wordphrase vocabulary 

# Open the file in write mode with 
for part_of_speech in ['adj', 'verb', 'adv']:
    with open(f"results_{part_of_speech}.txt", "w") as file:
        print(f"Results for vocabulary with just {part_of_speech}\n\n")
        file.write(f"Results for vocabulary with just {part_of_speech}\n\n")
        for name in ["CS", "EESS", "Math", "Phys", "Stat"]:
        # Load the framework
            print(name + " Results:")
            file.write(f"{name} Results:\n")
            model = MLE(f"distribution/{name}.parquet", pos=part_of_speech)
            for alpha in [0, 0.025, 0.05, 0.075, 0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25]:
                estimated, ci = model.inference(f"data/validation_data/{name}/ground_truth_alpha_{alpha}.parquet")
                error = abs(estimated - alpha)
                line_header = f"{'Ground Truth':>10},{'Prediction':>10},{'CI':>10},{'Error':>10}"
                line_data = f"{alpha:10.3f},{estimated:10.3f},{ci:10.3f},{error:10.3f}"
                print(line_header)
                print(line_data)
                file.write(line_header + "\n")
                file.write(line_data + "\n")
            print("=====================================")
            file.write("=====================================\n")
# Out:
# Results for vocabulary with just adj
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.014,     0.005,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.031,     0.007,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.039,     0.007,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.053,     0.009,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.073,     0.009,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.084,     0.009,     0.041
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.106,     0.010,     0.044
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.122,     0.010,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.135,     0.011,     0.065
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.148,     0.012,     0.077
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.176,     0.013,     0.074
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.024,     0.007,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.028,     0.007,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.046,     0.008,     0.004
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.055,     0.008,     0.020
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.077,     0.009,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.092,     0.010,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.114,     0.010,     0.036
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.135,     0.011,     0.040
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.152,     0.011,     0.048
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.175,     0.012,     0.050
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.194,     0.012,     0.056
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.006,     0.003,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.018,     0.004,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.035,     0.005,     0.015
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.049,     0.006,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.063,     0.006,     0.037
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.083,     0.007,     0.042
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.096,     0.007,     0.054
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.114,     0.008,     0.061
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.135,     0.008,     0.065
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.154,     0.009,     0.071
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.168,     0.009,     0.082
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.009,     0.005,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.024,     0.006,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.041,     0.007,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.053,     0.008,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.076,     0.009,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.098,     0.009,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.119,     0.011,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.122,     0.011,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.140,     0.012,     0.060
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.165,     0.012,     0.060
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.185,     0.013,     0.065
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.025,     0.007,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.043,     0.008,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.060,     0.009,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.091,     0.010,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.090,     0.010,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.118,     0.011,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.143,     0.012,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.151,     0.012,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.183,     0.012,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.193,     0.013,     0.032
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.221,     0.013,     0.029
# =====================================
# Results for vocabulary with just verb
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.030,     0.009,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.051,     0.011,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.073,     0.011,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.097,     0.012,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.106,     0.013,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.129,     0.013,     0.004
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.147,     0.014,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.178,     0.016,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.202,     0.016,     0.002
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.200,     0.016,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.232,     0.016,     0.018
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.054,     0.012,     0.054
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.081,     0.012,     0.056
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.107,     0.014,     0.057
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.125,     0.014,     0.050
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.152,     0.016,     0.052
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.173,     0.016,     0.048
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.209,     0.016,     0.059
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.233,     0.016,     0.058
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.269,     0.018,     0.069
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.278,     0.018,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.310,     0.018,     0.060
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.028,     0.006,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.063,     0.008,     0.038
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.089,     0.008,     0.039
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.127,     0.009,     0.052
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.152,     0.010,     0.052
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.187,     0.010,     0.062
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.220,     0.011,     0.070
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.251,     0.011,     0.076
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.280,     0.012,     0.080
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.303,     0.011,     0.078
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.337,     0.011,     0.087
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.043,     0.008,     0.043
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.066,     0.009,     0.041
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.101,     0.010,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.121,     0.010,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.143,     0.012,     0.043
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.170,     0.012,     0.045
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.202,     0.013,     0.052
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.225,     0.012,     0.050
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.247,     0.013,     0.047
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.278,     0.013,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.312,     0.013,     0.062
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.035,     0.009,     0.035
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.058,     0.010,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.080,     0.011,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.113,     0.013,     0.038
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.133,     0.012,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.158,     0.013,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.183,     0.013,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.203,     0.014,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.232,     0.015,     0.032
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.250,     0.015,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.275,     0.015,     0.025
# =====================================
# Results for vocabulary with just adv
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.040,     0.008,     0.040
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.062,     0.009,     0.037
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.082,     0.009,     0.032
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.101,     0.009,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.131,     0.010,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.151,     0.010,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.183,     0.010,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.197,     0.011,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.226,     0.012,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.252,     0.011,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.275,     0.012,     0.025
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.046,     0.008,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.071,     0.008,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.086,     0.009,     0.036
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.115,     0.010,     0.040
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.135,     0.010,     0.035
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.159,     0.010,     0.034
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.179,     0.011,     0.029
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.201,     0.011,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.221,     0.011,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.245,     0.012,     0.020
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.270,     0.011,     0.020
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.014,     0.005,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.039,     0.006,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.067,     0.008,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.092,     0.009,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.113,     0.009,     0.013
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.136,     0.010,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.164,     0.010,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.174,     0.011,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.211,     0.011,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.230,     0.011,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.257,     0.012,     0.007
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.057,     0.008,     0.057
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.090,     0.009,     0.065
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.112,     0.009,     0.062
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.130,     0.011,     0.055
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.159,     0.011,     0.059
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.185,     0.011,     0.060
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.212,     0.011,     0.062
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.231,     0.011,     0.056
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.255,     0.012,     0.055
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.289,     0.013,     0.064
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.311,     0.012,     0.061
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.030,     0.007,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.063,     0.008,     0.038
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.079,     0.009,     0.029
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.099,     0.009,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.127,     0.010,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.149,     0.010,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.165,     0.010,     0.015
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.185,     0.011,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.214,     0.011,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.237,     0.012,     0.012
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.267,     0.013,     0.017
# =====================================
