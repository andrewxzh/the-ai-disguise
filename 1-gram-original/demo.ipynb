# %%
from src.estimation import estimate_text_distribution
from src.MLE import MLE

# %%
# for each subject, estimate the distribution of human-written text and AI-generated text
for name in ["CS","EESS","Math","Phys","Stat"]:
    estimate_text_distribution(f"data/training_data/{name}/human_data.parquet",f"data/training_data/{name}/ai_data.parquet",f"distribution/{name}.parquet")

# %%
# for each subject, estimate the alpha value of mixed text and calculate the error
for name in ["CS","EESS","Math","Phys","Stat"]:
    # load the framework
    model=MLE(f"distribution/{name}.parquet")
    for alpha in [0,0.025,0.05,0.075,0.1,0.125,0.15,0.175,0.2,0.225,0.25]:
        estimated,ci=model.inference(f"data/validation_data/{name}/ground_truth_alpha_{alpha}.parquet")
        error=abs(estimated-alpha)
        print(f"{'Ground Truth':>10},{'Prediction':>10},{'CI':>10},{'Error':>10}")
        print(f"{alpha:10.3f},{estimated:10.3f},{ci:10.3f},{error:10.3f}")
    print("=====================================")
# Out:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.025,     0.003,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.054,     0.003,     0.029
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.080,     0.004,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.102,     0.004,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.128,     0.005,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.151,     0.005,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.174,     0.005,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.194,     0.005,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.223,     0.005,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.244,     0.006,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.270,     0.006,     0.020
# =====================================
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.026,     0.003,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.053,     0.003,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.077,     0.003,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.103,     0.004,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.130,     0.004,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.150,     0.005,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.172,     0.005,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.194,     0.005,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.220,     0.005,     0.020
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.243,     0.005,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.267,     0.006,     0.017
# =====================================
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.021,     0.002,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.045,     0.003,     0.020
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.072,     0.003,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.094,     0.004,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.114,     0.004,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.139,     0.004,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.161,     0.005,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.181,     0.005,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.205,     0.005,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.231,     0.005,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.249,     0.005,     0.001
# =====================================
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.026,     0.002,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.052,     0.003,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.075,     0.003,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.100,     0.004,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.122,     0.004,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.146,     0.004,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.170,     0.004,     0.020
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.191,     0.005,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.212,     0.005,     0.012
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.235,     0.005,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.258,     0.006,     0.008
# =====================================
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.020,     0.002,     0.020
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.051,     0.003,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.074,     0.003,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.098,     0.004,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.123,     0.004,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.144,     0.005,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.168,     0.005,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.189,     0.005,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.211,     0.005,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.236,     0.005,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.257,     0.006,     0.007
# =====================================

# %%
# for each subject, estimate the alpha value of mixed text and calculate the error with only a specifc wordphrase vocabulary 

# Open the file in write mode with 
for part_of_speech in ['adj', 'verb', 'adv']:
    with open(f"results_{part_of_speech}.txt", "w") as file:
        print(f"Results for vocabulary with just {part_of_speech}\n\n")
        file.write(f"Results for vocabulary with just {part_of_speech}\n\n")
        for name in ["CS", "EESS", "Math", "Phys", "Stat"]:
        # Load the framework
            print(name + " Results:")
            file.write(f"{name} Results:\n")
            model = MLE(f"distribution/{name}.parquet", pos=part_of_speech)
            for alpha in [0, 0.025, 0.05, 0.075, 0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25]:
                estimated, ci = model.inference(f"data/validation_data/{name}/ground_truth_alpha_{alpha}.parquet")
                error = abs(estimated - alpha)
                line_header = f"{'Ground Truth':>10},{'Prediction':>10},{'CI':>10},{'Error':>10}"
                line_data = f"{alpha:10.3f},{estimated:10.3f},{ci:10.3f},{error:10.3f}"
                print(line_header)
                print(line_data)
                file.write(line_header + "\n")
                file.write(line_data + "\n")
            print("=====================================")
            file.write("=====================================\n")
# Out:
# Results for vocabulary with just adj
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.002,     0.002,     0.002
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.034,     0.007,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.053,     0.008,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.079,     0.009,     0.004
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.113,     0.009,     0.013
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.136,     0.010,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.171,     0.010,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.181,     0.010,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.214,     0.010,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.241,     0.011,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.269,     0.012,     0.019
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.017,     0.006,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.034,     0.007,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.066,     0.008,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.089,     0.009,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.119,     0.010,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.146,     0.009,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.173,     0.010,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.198,     0.010,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.229,     0.011,     0.029
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.253,     0.011,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.284,     0.011,     0.034
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.001,     0.001,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.018,     0.003,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.041,     0.005,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.061,     0.005,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.083,     0.006,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.109,     0.006,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.128,     0.007,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.154,     0.007,     0.021
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.174,     0.008,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.200,     0.008,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.221,     0.009,     0.029
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.000,     0.000,     0.000
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.021,     0.005,     0.004
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.046,     0.006,     0.004
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.073,     0.008,     0.002
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.098,     0.008,     0.002
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.129,     0.008,     0.004
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.155,     0.009,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.181,     0.009,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.206,     0.010,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.234,     0.010,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.262,     0.010,     0.012
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.009,     0.006,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.042,     0.008,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.072,     0.008,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.108,     0.010,     0.033
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.122,     0.009,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.153,     0.010,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.182,     0.010,     0.032
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.207,     0.010,     0.032
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.235,     0.011,     0.035
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.261,     0.012,     0.036
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.289,     0.011,     0.039
# =====================================
# Results for vocabulary with just verb
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.001,     0.001,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.026,     0.005,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.051,     0.007,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.068,     0.007,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.099,     0.008,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.118,     0.008,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.147,     0.009,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.172,     0.009,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.202,     0.009,     0.002
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.220,     0.010,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.245,     0.010,     0.005
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.003,     0.003,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.028,     0.006,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.051,     0.006,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.075,     0.007,     0.000
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.107,     0.008,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.133,     0.008,     0.008
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.157,     0.009,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.180,     0.009,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.208,     0.009,     0.008
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.228,     0.010,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.261,     0.010,     0.011
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.000,     0.000,     0.000
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.020,     0.004,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.041,     0.005,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.069,     0.006,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.091,     0.006,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.119,     0.007,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.143,     0.007,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.170,     0.008,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.191,     0.008,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.214,     0.008,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.249,     0.008,     0.001
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.005,     0.004,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.032,     0.005,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.054,     0.007,     0.004
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.081,     0.007,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.104,     0.007,     0.004
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.134,     0.009,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.163,     0.009,     0.013
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.182,     0.009,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.195,     0.009,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.232,     0.010,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.259,     0.009,     0.009
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.001,     0.001,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.024,     0.005,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.047,     0.006,     0.003
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.073,     0.007,     0.002
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.095,     0.007,     0.005
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.126,     0.007,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.151,     0.008,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.171,     0.008,     0.004
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.198,     0.009,     0.002
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.225,     0.009,     0.000
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.250,     0.009,     0.000
# =====================================
# Results for vocabulary with just adv
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.019,     0.011,     0.019
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.031,     0.011,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.062,     0.012,     0.012
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.082,     0.013,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.125,     0.012,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.139,     0.013,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.178,     0.014,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.199,     0.014,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.226,     0.015,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.252,     0.016,     0.027
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.267,     0.015,     0.017
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.014,     0.011,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.047,     0.011,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.067,     0.012,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.097,     0.013,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.123,     0.013,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.151,     0.013,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.178,     0.013,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.195,     0.013,     0.020
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.223,     0.014,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.251,     0.014,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.263,     0.015,     0.013
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.016,     0.010,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.040,     0.011,     0.015
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.074,     0.012,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.101,     0.012,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.124,     0.013,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.147,     0.013,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.181,     0.014,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.188,     0.015,     0.013
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.228,     0.014,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.255,     0.015,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.277,     0.015,     0.027
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.044,     0.012,     0.044
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.074,     0.013,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.104,     0.012,     0.054
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.116,     0.014,     0.041
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.157,     0.014,     0.057
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.174,     0.014,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.203,     0.014,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.234,     0.014,     0.059
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.248,     0.014,     0.048
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.279,     0.014,     0.054
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.311,     0.015,     0.061
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.013,     0.010,     0.013
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.050,     0.012,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.075,     0.014,     0.025
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.091,     0.014,     0.016
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.124,     0.013,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.142,     0.014,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.174,     0.015,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.205,     0.015,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.236,     0.015,     0.036
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.268,     0.015,     0.043
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.290,     0.015,     0.040
# =====================================
