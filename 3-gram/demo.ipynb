# %%
from src.estimation import estimate_text_distribution
from src.MLE import MLE
import pandas as pd

# %%
# for each subject, estimate the distribution of human-written text and AI-generated text
for name in ["CS","EESS","Math","Phys","Stat"]:
    estimate_text_distribution(f"data/training_data/{name}/human_data.parquet",f"data/training_data/{name}/ai_data.parquet",f"distribution/{name}.parquet")

# %%
pd.read_parquet("data/training_data/CS/human_data.parquet")
# Out:
#                                           human_sentence  \
# 0      [particularly the proposed, the proposed sprea...
# 1      [this mixed approach, mixed approach has, appr...
# 2      [firstly observing the, observing the limited,...
# 3      [however existing methods, existing methods ei...
# 4      [in this task, this task a, task a fused, a fu...
# ...                                                  ...
# 37855  [active learning shows, learning shows promise...
# 37856  [finally simulations using, simulations using ...
# 37857  [in this paper, this paper we, paper we model,...
# 37858  [these results help, results help to, help to ...
# 37859  [intuitively a shorter, a shorter tree, shorte...
#
#                                                 sentence
# 0      particularly the proposed spreading curve view...
# 1      this mixed approach has rarely been applied in...
# 2      firstly observing the limited rotation invaria...
# 3      however existing methods either require expens...
# 4      in this task a fused image containing both the...
# ...                                                  ...
# 37855  active learning shows promise to decrease test...
# 37856  finally simulations using flashflow for load b...
# 37857  in this paper we model this intention as a lat...
# 37858  these results help to identify the most critic...
# 37859  intuitively a shorter tree with pure leaves ge...
#
# [37860 rows x 2 columns]

# %%
pd.read_parquet("data/validation_data/CS/ground_truth_alpha_0.1.parquet")
# Out:
#                                       inference_sentence  \
# 0      [however empirical studies, empirical studies ...
# 1      [inspired by our, by our work, our work on, wo...
# 2      [however if attacked, if attacked it, attacked...
# 3      [existing methods for, methods for speaker, fo...
# 4      [estimation of the, of the heart, the heart ra...
# ...                                                  ...
# 29995  [while achieving over, achieving over times, o...
# 29996  [moreover the research, the research provides,...
# 29997  [one approach to, approach to enhance, to enha...
# 29998  [exploiting internal spatial, internal spatial...
# 29999  [down sampling training, sampling training dat...
#
#                                                 sentence
# 0      however empirical studies show that linearizin...
# 1      inspired by our work on deep multimodal learni...
# 2      however if attacked it could still be compromi...
# 3      existing methods for speaker age estimation us...
# 4      estimation of the heart rate from facial video...
# ...                                                  ...
# 29995       while achieving over times inference speedup
# 29996  moreover the research provides theoretical evi...
# 29997  one approach to enhance secrecy is by studying...
# 29998  exploiting internal spatial geometric constrai...
# 29999  down sampling training data has long been show...
#
# [30000 rows x 2 columns]

# %%
# for each subject, estimate the alpha value of mixed text and calculate the error
for name in ["CS","EESS","Math","Phys","Stat"]:
    # load the framework
    print(name + " Results:")
    model=MLE(f"distribution/{name}.parquet")
    for alpha in [0,0.025,0.05,0.075,0.1,0.125,0.15,0.175,0.2,0.225,0.25]:
        estimated,ci=model.inference(f"data/validation_data/{name}/ground_truth_alpha_{alpha}.parquet")
        error=abs(estimated-alpha)
        print(f"{'Ground Truth':>10},{'Prediction':>10},{'CI':>10},{'Error':>10}")
        print(f"{alpha:10.3f},{estimated:10.3f},{ci:10.3f},{error:10.3f}")
    print("=====================================")
# Out:
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.049,     0.005,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.075,     0.005,     0.050
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.099,     0.006,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.126,     0.006,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.152,     0.006,     0.052
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.175,     0.007,     0.050
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.197,     0.007,     0.047
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.217,     0.007,     0.042
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.245,     0.008,     0.045
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.274,     0.007,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.296,     0.008,     0.046
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.058,     0.005,     0.058
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.090,     0.006,     0.065
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.113,     0.006,     0.063
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.138,     0.006,     0.063
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.166,     0.007,     0.066
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.190,     0.007,     0.065
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.213,     0.007,     0.063
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.237,     0.007,     0.062
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.262,     0.007,     0.062
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.282,     0.008,     0.057
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.311,     0.008,     0.061
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.079,     0.007,     0.079
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.116,     0.008,     0.091
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.148,     0.008,     0.098
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.181,     0.008,     0.106
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.210,     0.008,     0.110
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.240,     0.009,     0.115
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.269,     0.009,     0.119
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.292,     0.009,     0.117
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.314,     0.009,     0.114
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.349,     0.009,     0.124
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.365,     0.009,     0.115
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.054,     0.005,     0.054
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.076,     0.006,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.110,     0.006,     0.060
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.131,     0.006,     0.056
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.150,     0.007,     0.050
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.177,     0.007,     0.052
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.192,     0.008,     0.042
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.216,     0.008,     0.041
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.243,     0.008,     0.043
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.265,     0.008,     0.040
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.286,     0.008,     0.036
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.054,     0.006,     0.054
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.085,     0.006,     0.060
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.110,     0.007,     0.060
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.136,     0.007,     0.061
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.163,     0.007,     0.063
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.184,     0.007,     0.059
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.209,     0.008,     0.059
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.237,     0.008,     0.062
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.251,     0.008,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.281,     0.008,     0.056
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.306,     0.008,     0.056
# =====================================

# %%
# for each subject, estimate the alpha value of mixed text and calculate the error with only a specifc wordphrase vocabulary 

# Open the file in write mode with 
for part_of_speech in ['adj', 'verb', 'adv']:
    with open(f"results_{part_of_speech}.txt", "w") as file:
        print(f"Results for vocabulary with just {part_of_speech}\n\n")
        file.write(f"Results for vocabulary with just {part_of_speech}\n\n")
        for name in ["CS", "EESS", "Math", "Phys", "Stat"]:
        # Load the framework
            print(name + " Results:")
            file.write(f"{name} Results:\n")
            model = MLE(f"distribution/{name}.parquet", pos=part_of_speech)
            for alpha in [0, 0.025, 0.05, 0.075, 0.1, 0.125, 0.15, 0.175, 0.2, 0.225, 0.25]:
                estimated, ci = model.inference(f"data/validation_data/{name}/ground_truth_alpha_{alpha}.parquet")
                error = abs(estimated - alpha)
                line_header = f"{'Ground Truth':>10},{'Prediction':>10},{'CI':>10},{'Error':>10}"
                line_data = f"{alpha:10.3f},{estimated:10.3f},{ci:10.3f},{error:10.3f}"
                print(line_header)
                print(line_data)
                file.write(line_header + "\n")
                file.write(line_data + "\n")
            print("=====================================")
            file.write("=====================================\n")
# Out:
# Results for vocabulary with just adj
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.143,     0.013,     0.043
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.184,     0.014,     0.059
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.202,     0.013,     0.052
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.247,     0.016,     0.072
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.264,     0.015,     0.064
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.292,     0.016,     0.067
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.320,     0.015,     0.070
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.039,     0.010,     0.039
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.078,     0.012,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.099,     0.012,     0.049
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.130,     0.012,     0.055
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.156,     0.013,     0.056
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.178,     0.014,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.214,     0.014,     0.064
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.237,     0.015,     0.062
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.253,     0.015,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.293,     0.014,     0.068
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.318,     0.015,     0.068
# =====================================
# Results for vocabulary with just adv
#
#
# CS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.022,     0.018,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.043,     0.021,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.060,     0.023,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.084,     0.023,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.109,     0.025,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.142,     0.026,     0.017
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.164,     0.025,     0.014
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.168,     0.029,     0.007
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.201,     0.029,     0.001
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.238,     0.032,     0.013
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.272,     0.031,     0.022
# =====================================
# EESS Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.028,     0.018,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.071,     0.022,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.061,     0.023,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.105,     0.026,     0.030
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.151,     0.032,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.173,     0.029,     0.048
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.189,     0.029,     0.039
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.209,     0.032,     0.034
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.253,     0.034,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.278,     0.034,     0.053
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.302,     0.032,     0.052
# =====================================
# Math Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.272,     0.057,     0.272
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.298,     0.051,     0.273
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.368,     0.048,     0.318
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.334,     0.049,     0.259
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.372,     0.049,     0.272
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.380,     0.052,     0.255
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.367,     0.053,     0.217
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.420,     0.048,     0.245
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.454,     0.049,     0.254
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.484,     0.048,     0.259
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.449,     0.048,     0.199
# =====================================
# Phys Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.022,     0.022,     0.022
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.089,     0.044,     0.064
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.101,     0.052,     0.051
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.084,     0.047,     0.009
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.131,     0.048,     0.031
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.171,     0.051,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.246,     0.048,     0.096
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.229,     0.049,     0.054
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.266,     0.053,     0.066
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.271,     0.051,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.305,     0.051,     0.055
# =====================================
# Stat Results:
# Ground Truth,Prediction,        CI,     Error
#      0.000,     0.011,     0.011,     0.011
# Ground Truth,Prediction,        CI,     Error
#      0.025,     0.053,     0.023,     0.028
# Ground Truth,Prediction,        CI,     Error
#      0.050,     0.073,     0.025,     0.023
# Ground Truth,Prediction,        CI,     Error
#      0.075,     0.085,     0.027,     0.010
# Ground Truth,Prediction,        CI,     Error
#      0.100,     0.118,     0.028,     0.018
# Ground Truth,Prediction,        CI,     Error
#      0.125,     0.179,     0.033,     0.054
# Ground Truth,Prediction,        CI,     Error
#      0.150,     0.196,     0.033,     0.046
# Ground Truth,Prediction,        CI,     Error
#      0.175,     0.201,     0.031,     0.026
# Ground Truth,Prediction,        CI,     Error
#      0.200,     0.194,     0.029,     0.006
# Ground Truth,Prediction,        CI,     Error
#      0.225,     0.249,     0.033,     0.024
# Ground Truth,Prediction,        CI,     Error
#      0.250,     0.285,     0.037,     0.035
# =====================================
